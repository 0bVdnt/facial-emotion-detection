# %%
import os
import cv2
import math
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, GlobalAvgPool2D, GlobalMaxPool2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.utils import plot_model

from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
INPUT_PATH = "../input/fer13-cleaned-dataset/"

# %%
total_images = 0
for dir_ in os.listdir(INPUT_PATH):
    count = 0
    for f in os.listdir(INPUT_PATH + dir_ + "/"):
        count += 1
        total_images += 1
    print(f"{dir_} has {count} number of images")
    
print(f"\ntotal images are {total_images}")
# Out:
# fear has 2535 number of images
# Angry has 2832 number of images
# Neutral has 4295 number of images
# disgust has 380 number of images
# Happy has 6834 number of images
#
# total images are 16876

# %%
TOP_EMOTIONS = ["fear", "Happy", "Neutral", "Angry"]
total_images -= 380
total_images
# Out:
# 16496

# %%
img_arr = np.empty(shape=(total_images,48,48,3))
img_label = np.empty(shape=(total_images))
label_to_text = {}

i = 0
e = 0
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        label_to_text[e] = dir_
        for f in os.listdir(INPUT_PATH + dir_ + "/"):
            img_arr[i] = cv2.imread(INPUT_PATH + dir_ + "/" + f)
            img_label[i] = e
            i += 1
        print(f"loaded all {dir_} images to numpy arrays")
        e += 1

img_arr.shape, img_label
# Out:
# loaded all fear images to numpy arrays
# loaded all Angry images to numpy arrays
# loaded all Neutral images to numpy arrays
# loaded all Happy images to numpy arrays
# ((16496, 48, 48, 3), array([0., 0., 0., ..., 3., 3., 3.]))

# %%
label_to_text
# Out:
# {0: 'fear', 1: 'Angry', 2: 'Neutral', 3: 'Happy'}

# %%
fig = pyplot.figure(1, (8,8))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label==k)[0], size=4, replace=False)
    sample_images = img_arr[sample_indices]
    for img in sample_images:
        idx += 1
        ax = pyplot.subplot(4,4,idx)
        ax.imshow(img[:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])
        pyplot.tight_layout()

# %%
img_label = np_utils.to_categorical(img_label)
img_label.shape
# Out:
# (16496, 4)

# %% [markdown]
# `Splitting the data into training and validation set.`

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=0.9, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14846, 48, 48, 3), (1650, 48, 48, 3), (14846, 4), (1650, 4))

# %%
del img_arr
del img_label

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]
num_classes = y_train.shape[1]

# %%
mobile_net = MobileNet(
    input_shape = (img_width, img_height, img_depth),
    include_top = False,
    weights = "imagenet",
    classes = num_classes
)

x = mobile_net.layers[-14].output
global_pool = GlobalMaxPool2D(name="global_pool")(x)
out = Dense(num_classes, activation="softmax", name="out_layer")(global_pool)

model = Model(inputs=mobile_net.input, outputs=out)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_applications/mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50, to_file='mobilenet.png')

# %%
for layer in model.layers[:15]:
    layer.trainable = False

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    zca_whitening=False,
)
train_datagen.fit(X_train)

# %%
"""
I used two callbacks one is `early stopping` for avoiding overfitting training data
and other `ReduceLROnPlateau` for learning rate.
"""
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00008,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.25,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
    early_stopping,
    lr_scheduler,
]

# %%
batch_size = 25
epochs = 40

optims = [
    optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07),
    optimizers.Adam(0.01),
]

model.compile(
        loss='categorical_crossentropy',
        optimizer=optims[1],
        metrics=['accuracy']
)

history = model.fit_generator(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data=(X_test, y_test),
    steps_per_epoch=len(X_train) / batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Train for 593.84 steps, validate on 1650 samples
# Epoch 1/40
# 594/593 [==============================] - 20s 33ms/step - loss: 1.3942 - accuracy: 0.4676 - val_loss: 1.0826 - val_accuracy: 0.5345
# Epoch 2/40
# 594/593 [==============================] - 14s 24ms/step - loss: 1.0053 - accuracy: 0.5932 - val_loss: 1.1887 - val_accuracy: 0.6042
# Epoch 3/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.9227 - accuracy: 0.6262 - val_loss: 0.9846 - val_accuracy: 0.6285
# Epoch 4/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.8812 - accuracy: 0.6464 - val_loss: 0.9714 - val_accuracy: 0.6115
# Epoch 5/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.8509 - accuracy: 0.6674 - val_loss: 1.0193 - val_accuracy: 0.6006
# Epoch 6/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.8312 - accuracy: 0.6691 - val_loss: 1.0917 - val_accuracy: 0.6121
# Epoch 7/40
# 591/593 [============================>.] - ETA: 0s - loss: 0.8123 - accuracy: 0.6785
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 594/593 [==============================] - 14s 24ms/step - loss: 0.8140 - accuracy: 0.6778 - val_loss: 0.9657 - val_accuracy: 0.6133
# Epoch 8/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.7415 - accuracy: 0.7087 - val_loss: 0.7748 - val_accuracy: 0.6897
# Epoch 9/40
# 594/593 [==============================] - 15s 24ms/step - loss: 0.7165 - accuracy: 0.7200 - val_loss: 0.7593 - val_accuracy: 0.6988
# Epoch 10/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.7042 - accuracy: 0.7242 - val_loss: 0.7667 - val_accuracy: 0.7006
# Epoch 11/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.6921 - accuracy: 0.7290 - val_loss: 0.7133 - val_accuracy: 0.7248
# Epoch 12/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.6840 - accuracy: 0.7350 - val_loss: 0.7070 - val_accuracy: 0.7212
# Epoch 13/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.6717 - accuracy: 0.7381 - val_loss: 0.7826 - val_accuracy: 0.6970
# Epoch 14/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.6647 - accuracy: 0.7386 - val_loss: 0.7281 - val_accuracy: 0.7067
# Epoch 15/40
# 591/593 [============================>.] - ETA: 0s - loss: 0.6569 - accuracy: 0.7478
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 594/593 [==============================] - 14s 24ms/step - loss: 0.6567 - accuracy: 0.7478 - val_loss: 0.7323 - val_accuracy: 0.7133
# Epoch 16/40
# 594/593 [==============================] - 15s 24ms/step - loss: 0.6308 - accuracy: 0.7523 - val_loss: 0.6952 - val_accuracy: 0.7400
# Epoch 17/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.6173 - accuracy: 0.7564 - val_loss: 0.7025 - val_accuracy: 0.7303
# Epoch 18/40
# 594/593 [==============================] - 15s 25ms/step - loss: 0.6148 - accuracy: 0.7585 - val_loss: 0.6874 - val_accuracy: 0.7321
# Epoch 19/40
# 594/593 [==============================] - 15s 25ms/step - loss: 0.6015 - accuracy: 0.7670 - val_loss: 0.6776 - val_accuracy: 0.7370
# Epoch 20/40
# 593/593 [============================>.] - ETA: 0s - loss: 0.6034 - accuracy: 0.7688
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 594/593 [==============================] - 15s 24ms/step - loss: 0.6030 - accuracy: 0.7689 - val_loss: 0.6848 - val_accuracy: 0.7303
# Epoch 21/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.5844 - accuracy: 0.7738 - val_loss: 0.6799 - val_accuracy: 0.7364
# Epoch 22/40
# 594/593 [==============================] - 15s 24ms/step - loss: 0.5880 - accuracy: 0.7684 - val_loss: 0.6873 - val_accuracy: 0.7352
# Epoch 23/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.5830 - accuracy: 0.7706 - val_loss: 0.6809 - val_accuracy: 0.7370
# Epoch 24/40
# 591/593 [============================>.] - ETA: 0s - loss: 0.5823 - accuracy: 0.7725
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 594/593 [==============================] - 14s 24ms/step - loss: 0.5814 - accuracy: 0.7728 - val_loss: 0.6864 - val_accuracy: 0.7388
# Epoch 25/40
# 594/593 [==============================] - 15s 24ms/step - loss: 0.5776 - accuracy: 0.7727 - val_loss: 0.6824 - val_accuracy: 0.7364
# Epoch 26/40
# 594/593 [==============================] - 14s 24ms/step - loss: 0.5788 - accuracy: 0.7726 - val_loss: 0.6815 - val_accuracy: 0.7352
# Epoch 27/40
# 593/593 [============================>.] - ETA: 0s - loss: 0.5784 - accuracy: 0.7750Restoring model weights from the end of the best epoch.
# 594/593 [==============================] - 15s 25ms/step - loss: 0.5783 - accuracy: 0.7752 - val_loss: 0.6823 - val_accuracy: 0.7333
# Epoch 00027: early stopping

# %%
model_yaml = model.to_yaml()
with open("model_mobelnet.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
    
model.save("model_moblenet.h5")

# %%
sns.set()
fig = pyplot.figure(0, (12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(history.epoch, history.history['accuracy'], label='train')
sns.lineplot(history.epoch, history.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(history.epoch, history.history['loss'], label='train')
sns.lineplot(history.epoch, history.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.savefig('epoch_history_mobilenet.png')
pyplot.show()

# %%
label_to_text
# Out:
# {0: 'fear', 1: 'Angry', 2: 'Neutral', 3: 'Happy'}

# %%
text_to_label = dict((v,k) for k,v in label_to_text.items())
text_to_label
# Out:
# {'fear': 0, 'Angry': 1, 'Neutral': 2, 'Happy': 3}

# %%
yhat_test = np.argmax(model.predict(X_test), axis=1)
ytest_ = np.argmax(y_test, axis=1)

scikitplot.metrics.plot_confusion_matrix(ytest_, yhat_test, figsize=(7,7))
pyplot.savefig("confusion_matrix_mobilenet.png")

test_accu = np.sum(ytest_ == yhat_test) / len(ytest_) * 100
print(f"test accuracy: {round(test_accu, 4)} %\n\n")

print(classification_report(ytest_, yhat_test))
# Out:
# test accuracy: 74.0 %
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.56      0.59       253
#            1       0.69      0.47      0.56       283
#            2       0.65      0.73      0.69       430
#            3       0.84      0.93      0.88       684
#
#     accuracy                           0.74      1650
#    macro avg       0.70      0.67      0.68      1650
# weighted avg       0.73      0.74      0.73      1650

# %%
np.random.seed(42)
fear_imgs = np.random.choice(np.where(y_test[:, text_to_label["fear"]]==1)[0], size=9, replace=False)
angry_imgs = np.random.choice(np.where(y_test[:, text_to_label["Angry"]]==1)[0], size=9, replace=False)

fig = pyplot.figure(1, (18, 4))

for i, (fear_idx, angry_idx) in enumerate(zip(fear_imgs, angry_imgs)):
        sample_img = X_test[fear_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = pyplot.subplot(2, 9, i+1)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:fear, p:{pred}")

        sample_img = X_test[angry_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = pyplot.subplot(2, 9, i+10)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:angry, p:{pred}")

        pyplot.tight_layout()

# %%
def plot_miss_classified(emotion):
    miss_happy_indices = np.where((ytest_ != yhat_test) & (ytest_==text_to_label[emotion]))[0]
    print(f"total {len(miss_happy_indices)} miss labels out of {len(np.where(ytest_==text_to_label[emotion])[0])} for emotion {emotion}")

    cols = 15
    rows = math.ceil(len(miss_happy_indices) / cols)
    fig = pyplot.figure(1, (20, rows * 2))

    for i,idx in enumerate(miss_happy_indices):
        sample_img = X_test[idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = pyplot.subplot(rows,cols,i+1)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"p:{pred}")

# %%
plot_miss_classified(emotion="Happy")
# Out:
# total 49 miss labels out of 684 for emotion Happy

# %%
plot_miss_classified(emotion="fear")
# Out:
# total 112 miss labels out of 253 for emotion fear

# %%
plot_miss_classified(emotion="Neutral")
# Out:
# total 117 miss labels out of 430 for emotion Neutral
